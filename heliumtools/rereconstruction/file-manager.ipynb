# %%
from heliumtools.misc.gather_data import *
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# export_data_set_to_pickle(folder ="/home/victor/Data/014_ter", ROI = {"T":[0, 400]}) 
data0 = pd.read_pickle("/home/victor/Data/014/dataset.pkl")
data1 = pd.read_pickle("/home/victor/Data/014_bis/dataset.pkl")
data2 = pd.read_pickle("/home/victor/Data/014_ter/dataset.pkl")


def load_files(folder):

    files = select_atoms_in_folder(folder)
    df = []
    for i, f in enumerate(files):
        seq, cycle_id = return_cycle_from_path(f, show_error=True)
        data = load_times_of_atoms(f)
        data = pd.DataFrame(data = np.transpose(np.array(data)), columns= ["X1", "X2", "Y1", "Y2"])
        data["Cycle"] = cycle_id
        df.append(data)
        
    df = pd.concat(df)
    df.to_pickle(os.path.join(folder, "raw_data.pkl"))
    return data

load_files("/home/victor/Data/014_ter/")
# data0 = pd.read_pickle("/home/victor/Data/014/raw_data.pkl")
# data1 = pd.read_pickle("/home/victor/Data/014_bis/raw_data.pkl")
# data2 = pd.read_pickle("/home/victor/Data/014_ter/raw_data.pkl")
# Out:
#               X1          X2          Y1          Y2      Cycle
# 0        1180613     1181121     1180949     1180763  105355043
# 1        2874680     2875159     2875012     2874805  105355043
# 2        3194513     3195049     3194859     3194681  105355043
# 3        4128593     4129077     4128891     4128760  105355043
# 4       10568807    10569231    10569101    10568916  105355043
# ...          ...         ...         ...         ...        ...
# 2398  3107868225  3107868680  3107868554  3107868330  105355043
# 2399  3173441406  3173441205  3173441502  3173441063  105355043
# 2400  3244327892  3244327543  3244327907  3244327481  105355043
# 2401  3249492304  3249492182  3249492034  3249492425  105355043
# 2402  3308926895  3308926668  3308926818  3308926702  105355043
#
# [2403 rows x 5 columns]

# %%
df = pd.concat([data1, data2]).drop_duplicates(keep = False, ignore_index = True)

# %%
sns.histplot(data = df, x = "X", y = "Y")
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
plt.hist(df["T"], bins = np.linspace(280, 320, 100))
# Out:
# (array([0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         2.200e+01, 1.435e+03, 1.410e+02, 3.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
import glob
import shutil
folder = "/mnt/manip_E/2022/07/18/004/*.times"
print("hello")
for file in glob.glob(folder):
    print(file)
    try:
        shutil.copy(file, file + 'x2')
    except:
        pass
# Out:
# hello
# /mnt/manip_E/2022/07/18/004/004_001.times
# /mnt/manip_E/2022/07/18/004/004_002.times
# /mnt/manip_E/2022/07/18/004/004_003.times
# /mnt/manip_E/2022/07/18/004/004_004.times
# /mnt/manip_E/2022/07/18/004/004_005.times
# /mnt/manip_E/2022/07/18/004/004_006.times
# /mnt/manip_E/2022/07/18/004/004_007.times
# /mnt/manip_E/2022/07/18/004/004_008.times
# /mnt/manip_E/2022/07/18/004/004_009.times
# /mnt/manip_E/2022/07/18/004/004_010.times
# /mnt/manip_E/2022/07/18/004/004_011.times
# /mnt/manip_E/2022/07/18/004/004_012.times
# /mnt/manip_E/2022/07/18/004/004_013.times
# /mnt/manip_E/2022/07/18/004/004_014.times
# /mnt/manip_E/2022/07/18/004/004_015.times
# /mnt/manip_E/2022/07/18/004/004_016.times
# /mnt/manip_E/2022/07/18/004/004_017.times
# /mnt/manip_E/2022/07/18/004/004_018.times
# /mnt/manip_E/2022/07/18/004/004_019.times
# /mnt/manip_E/2022/07/18/004/004_020.times
# /mnt/manip_E/2022/07/18/004/004_021.times
# /mnt/manip_E/2022/07/18/004/004_022.times
# ...
